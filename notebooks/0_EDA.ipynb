# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

import sys
sys.path.append('../')

# %%
from src.config import (
    path_tracks_temp,
    path_persons_temp,
    path_sessions_temp
)

# %%
def dict_unique_counter(arr):
    return dict(zip(*np.unique(arr, return_counts=True)))

# %% [markdown]
# # Чтение файлов

# %% [markdown]
# ### Данные об исполнителях

# %%
# исполнители
persons = pd.read_csv(path_persons_temp)
print(persons.shape)
persons.head()

# поле "person_name" по фиксированному "person_id" может именть
# пример с "David Guetta"
# будем использовать для декодинга person_id
persons[persons['person_id'].isin([227])]
# Out:
# (595049, 3)
#         person_id                                       person_name  \
# 4673          227                       David+Guetta+&+Nicky+Romero
# 12079         227                          David+Guetta,+Sam+Martin
# 17306         227                     David+Guetta+ft.+Chris+Willis
# 31403         227              David+Guetta+-+Ne-Yo+-+Kelly+Rowland
# 38019         227  David+Guetta+&+Chris+Willis+Feat.+Fergie+&+LMFAO
# ...           ...                                               ...
# 570347        227          David+Guetta+&+Alesso+feat.+Tegan+&+Sara
# 572905        227                    David+Guetta+ft.+Kelly+Rowland
# 578055        227         David+Guetta+Feat+Lil+Wayne+&+Chris+Brown
# 588531        227  David+Guetta+&+Glowinthedark+feat.+Harrison+Shaw
# 590460        227           David+Guetta+&+Avicii+vs.+Laidback+Luke
#
#                                  person_MBID
# 4673                                     NaN
# 12079   1bb1eec6-88c3-4028-8920-a985c4b9081a
# 17306   1bb1eec6-88c3-4028-8920-a985c4b9081a
# 31403   1bb1eec6-88c3-4028-8920-a985c4b9081a
# 38019   1bb1eec6-88c3-4028-8920-a985c4b9081a
# ...                                      ...
# 570347                                   NaN
# 572905  1bb1eec6-88c3-4028-8920-a985c4b9081a
# 578055  1bb1eec6-88c3-4028-8920-a985c4b9081a
# 588531                                   NaN
# 590460                                   NaN
#
# [69 rows x 3 columns]

# %% [markdown]
# ### Данные о треках (справочник `треки`-`исполнитель`-`число_проигрываний`)
# Некоторые треки и исполнители имеют мало прослушиваний, но будем работать со всеми исполнителями.

# %%
# треки
tracks = pd.read_csv(path_tracks_temp)
print(tracks.shape)
tracks.head()
# Out:
# (4544643, 3)
#    track_id  playcount  person_id
# 0         0        4.0          0
# 1         1      495.0          1
# 2         2        2.0          2
# 3         3        2.0          3
# 4         4        1.0          4

# %%
tracks['track_id'].nunique(), tracks['person_id'].nunique()
# Out:
# (4519105, 560927)

# %%
# расчет числа проигрываний каждого исполнителя.
persons_playcount = tracks.groupby(['person_id'], as_index=False)['playcount'].sum()
persons_playcount
# Out:
#         person_id  playcount
# 0               0        4.0
# 1               1      495.0
# 2               2        2.0
# 3               3        2.0
# 4               4        1.0
# ...           ...        ...
# 560922     595136        0.0
# 560923     595137        0.0
# 560924     595138        0.0
# 560925     595139        0.0
# 560926     595140        0.0
#
# [560927 rows x 2 columns]

# %%
persons_playcount['playcount'].describe(percentiles=[
    0.025, 0.05, 0.25, 0.5, 0.75, 0.95, 0.9725
])
# Out:
# count    5.609270e+05
# mean     1.219149e+04
# std      9.367164e+04
# min     -6.000000e+00
# 2.5%     0.000000e+00
# 5%       0.000000e+00
# 25%      6.000000e+00
# 50%      1.160000e+02
# 75%      1.248000e+03
# 95%      3.520810e+04
# 97.2%    8.508707e+04
# max      9.400856e+06
# Name: playcount, dtype: float64

# %%
mask_popular_persons = (persons_playcount['playcount'] >= 140000)

print(mask_popular_persons.sum() / persons_playcount.shape[0])

popular_persons = persons_playcount.loc[mask_popular_persons, 'person_id'].values
print(popular_persons.shape)
popular_persons
# Out:
# 0.018392767686347778
# (10317,)
# array([    78,    109,    129, ..., 468284, 468998, 472663])

# %% [markdown]
# ### Данные о сессиях с прослушиванием треков

# %%
# сессии с прослушиванием
sessions = pd.read_csv(path_sessions_temp)
print(sessions.shape)
sessions.head()
# Out:
# (28178697, 7)
#    session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 0      287144  1390231051      4547         23    44361   4698874
# 1      287144  1390231051      4547         23    44361    838286
# 2      287144  1390231051      4547         23    44361   2588097
# 3      287144  1390231051      4547         23    44361   2746740
# 4      287144  1390231051      4547         23    44361   3873988
#
#    track_playratio
# 0              NaN
# 1             1.01
# 2             1.01
# 3             1.44
# 4             1.01

# %%
sessions.head(30)
# Out:
#     session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 0       287144  1390231051      4547         23    44361   4698874
# 1       287144  1390231051      4547         23    44361    838286
# 2       287144  1390231051      4547         23    44361   2588097
# 3       287144  1390231051      4547         23    44361   2746740
# 4       287144  1390231051      4547         23    44361   3873988
# 5       287144  1390231051      4547         23    44361    808046
# 6       287144  1390231051      4547         23    44361   2588498
# 7       287144  1390231051      4547         23    44361   2492893
# 8       287144  1390231051      4547         23    44361   2168413
# 9       287144  1390231051      4547         23    44361   1778345
# 10      287144  1390231051      4547         23    44361   2989691
# 11      287144  1390231051      4547         23    44361   4698875
# 12      287144  1390231051      4547         23    44361   2985955
# 13      287144  1390231051      4547         23    44361   4698876
# 14      287144  1390231051      4547         23    44361   1728736
# 15      287144  1390231051      4547         23    44361   2615446
# 16      287144  1390231051      4547         23    44361   4698877
# 17      287144  1390231051      4547         23    44361   4698878
# 18      287144  1390231051      4547         23    44361    515524
# 19      287144  1390231051      4547         23    44361   4698879
# 20      287144  1390231051      4547         23    44361   4698880
# 21      287144  1390231051      4547         23    44361   2444241
# 22      287144  1390231051      4547         23    44361   4698881
# 23      287145  1390241844      2907         11    44361    455834
# 24      287145  1390241844      2907         11    44361   2460503
# 25      287145  1390241844      2907         11    44361   1999451
# 26      287145  1390241844      2907         11    44361   3257000
# 27      287145  1390241844      2907         11    44361   2765459
# 28      287145  1390241844      2907         11    44361   4698882
# 29      287145  1390241844      2907         11    44361   1311408
#
#     track_playratio
# 0               NaN
# 1              1.01
# 2              1.01
# 3              1.44
# 4              1.01
# 5              1.01
# 6              1.01
# 7              1.02
# 8              1.02
# 9              1.07
# 10             0.99
# 11              NaN
# 12             1.54
# 13              NaN
# 14             0.96
# 15             0.93
# 16              NaN
# 17              NaN
# 18             1.10
# 19              NaN
# 20              NaN
# 21             1.04
# 22             1.00
# 23             1.01
# 24             0.18
# 25             1.02
# 26             0.33
# 27             1.06
# 28              NaN
# 29             0.89

# %%
sessions['numtracks'].describe(percentiles=[
    0.025, 0.05, 0.25, 0.5, 0.75, 0.95, 0.9725
])
# Out:
# count    2.817870e+07
# mean     4.142387e+01
# std      8.674240e+01
# min      1.000000e+00
# 2.5%     2.000000e+00
# 5%       3.000000e+00
# 25%      1.000000e+01
# 50%      2.100000e+01
# 75%      4.500000e+01
# 95%      1.410000e+02
# 97.2%    2.000000e+02
# max      4.914000e+03
# Name: numtracks, dtype: float64

# %%
(sessions['numtracks'] > 30).sum() / sessions.shape[0]
# Out:
# 0.3694823078583087

# %%
sessions[sessions['track_playratio'].isin([np.nan])]
# Out:
#           session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 0             287144  1390231051      4547         23    44361   4698874
# 11            287144  1390231051      4547         23    44361   4698875
# 13            287144  1390231051      4547         23    44361   4698876
# 16            287144  1390231051      4547         23    44361   4698877
# 17            287144  1390231051      4547         23    44361   4698878
# ...              ...         ...       ...        ...      ...       ...
# 28178683      540638  1415960966     18220         78    24700   1916497
# 28178688      540638  1415960966     18220         78    24700   1798283
# 28178691      540638  1415960966     18220         78    24700   1174854
# 28178692     2480032  1407938059        -1          1    33058    906373
# 28178696     2480033  1407939579       556          4    33058   3293580
#
#           track_playratio
# 0                     NaN
# 11                    NaN
# 13                    NaN
# 16                    NaN
# 17                    NaN
# ...                   ...
# 28178683              NaN
# 28178688              NaN
# 28178691              NaN
# 28178692              NaN
# 28178696              NaN
#
# [4235971 rows x 7 columns]

# %%
sessions['track_playratio'].describe(percentiles=[
    0.025, 0.05, 0.25, 0.5, 0.75, 0.95, 0.9725
])
# Out:
# count    2.394273e+07
# mean     1.131717e+00
# std      2.026694e+00
# min      0.000000e+00
# 2.5%     1.000000e-01
# 5%       5.000000e-01
# 25%      9.900000e-01
# 50%      1.000000e+00
# 75%      1.040000e+00
# 95%      1.910000e+00
# 97.2%    2.530000e+00
# max      7.970000e+02
# Name: track_playratio, dtype: float64

# %% [markdown]
# # Переход к истории прослушивания исполнителей

# %%
# переход от истории прослушиваний треков к истории прослушивания исполнителей
sessions_extend = sessions.merge(
    tracks,
    how='inner',
    on=['track_id']
)

# %%
print(sessions_extend.shape)
sessions_extend.head()
# Out:
# (30732788, 9)
#    session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 0      287144  1390231051      4547         23    44361   4698874
# 1      287144  1390231051      4547         23    44361    838286
# 2      982046  1405452797      6892         29    32894    838286
# 3      982049  1405702985     15646         68    32894    838286
# 4     1873088  1406217037        -1          1    23183    838286
#
#    track_playratio  playcount  person_id
# 0              NaN        NaN     142266
# 1             1.01      212.0     107103
# 2             1.00      212.0     107103
# 3             1.00      212.0     107103
# 4              NaN      212.0     107103

# %%
# sessions_extend.groupby(['timestamp'], as_index=False)['track_id'].count()

# %%
del sessions, tracks

# %%
# возьмем сессии популярных исполнителей, отобранных выше
# sessions_extend = 
sessions_extend[
    sessions_extend['person_id'].isin(popular_persons)
    & (sessions_extend['numtracks'] > 30)
]
# Out:
#           session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 3             982049  1405702985     15646         68    32894    838286
# 5             961319  1416339976      8433         34    28231    838286
# 6            2497483  1416525632     22703         88    37873    838286
# 11           1706581  1413786198     28830        111    12776    838286
# 13            386789  1406408030      7921         31    41047    838286
# ...              ...         ...       ...        ...      ...       ...
# 30732747     2575972  1409144730     40506        187    29398   2376711
# 30732751     2575972  1409144730     40506        187    29398   2696663
# 30732757      540634  1414662293     10173         43    24700   2123597
# 30732758      540634  1414662293     10173         43    24700   2123592
# 30732771      540638  1415960966     18220         78    24700   2912388
#
#           track_playratio  playcount  person_id
# 3                    1.00      212.0     107103
# 5                    1.01      212.0     107103
# 6                    1.01      212.0     107103
# 11                   1.01      212.0     107103
# 13                   1.10      212.0     107103
# ...                   ...        ...        ...
# 30732747             1.06     2434.0     297130
# 30732751             0.84       87.0     338072
# 30732757             0.97      218.0     266608
# 30732758             1.23      151.0     266608
# 30732771             0.96      793.0     361925
#
# [7948089 rows x 9 columns]

# %%
print(sessions_extend.shape)
sessions_extend.head()
# Out:
# (9195167, 9)
#     session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 3       982049  1405702985     15646         68    32894    838286
# 5       961319  1416339976      8433         34    28231    838286
# 6      2497483  1416525632     22703         88    37873    838286
# 11     1706581  1413786198     28830        111    12776    838286
# 13      386789  1406408030      7921         31    41047    838286
#
#     track_playratio  playcount  person_id
# 3              1.00      212.0     107103
# 5              1.01      212.0     107103
# 6              1.01      212.0     107103
# 11             1.01      212.0     107103
# 13             1.10      212.0     107103

# %%
# %%time
session_neighbours = sessions_extend.groupby(['session_id'])['person_id'].unique()
# Out:
# CPU times: user 16.9 s, sys: 323 ms, total: 17.3 s
# Wall time: 17.1 s

# %%
# %%time
session_neighbours = [
    (person, session[session != person])
    for session in session_neighbours
    for person in session
]
# Out:
# CPU times: user 7.94 s, sys: 1.68 s, total: 9.62 s
# Wall time: 9.63 s

# %%
# %%time
# session_neighbours = [
#     (person, dict_unique_counter(session[session != person]))
#     for session in session_neighbours
#     for person in session
# ]

# %%
session_neighbours = pd.DataFrame(
    session_neighbours,
    columns=['person_id', 'session_neighbours']
)

# %%
session_neighbours['len'] = session_neighbours['session_neighbours'].apply(len)
session_neighbours = session_neighbours[session_neighbours['len'] != 0]

# %%
# (session_neighbours['len'] > 10).sum() / session_neighbours.shape[0]

# %%
session_neighbours.head(15)
# Out:
#     person_id                                 session_neighbours  len
# 0      325704                    [324951, 321482, 209910, 45072]    4
# 1      324951                    [325704, 321482, 209910, 45072]    4
# 2      321482                    [325704, 324951, 209910, 45072]    4
# 3      209910                    [325704, 324951, 321482, 45072]    4
# 4       45072                   [325704, 324951, 321482, 209910]    4
# 5      435780                            [247876, 372354, 31691]    3
# 6      247876                            [435780, 372354, 31691]    3
# 7      372354                            [435780, 247876, 31691]    3
# 8       31691                           [435780, 247876, 372354]    3
# 9      192567                                            [31691]    1
# 10      31691                                           [192567]    1
# 12     447521                                            [55438]    1
# 13      55438                                           [447521]    1
# 14     134615  [28445, 376876, 377440, 303680, 169999, 184263...    8
# 15      28445  [134615, 376876, 377440, 303680, 169999, 18426...    8

# %%
# # df_lst = []
# for _, group in session_neighbours[session_neighbours['person_id'].isin([341684])].groupby(['person_id']):
#     print(np.concatenate(group['session_neighbours'].values))
#     break

# %%
session_neighbours['person_id'].unique()
# Out:
# array([325704, 324951, 321482, ..., 345400, 212554, 299374])

# %%
# # расчет около 45 минут
# df_lst = []
# for person in tqdm(session_neighbours['person_id'].unique()):
#     mask_person = session_neighbours['person_id'].isin([person])
#     neighbours = np.concatenate(
#         session_neighbours.loc[mask_person, 'session_neighbours'].values
#     )
#     neighbours_string = ' '.join(map(str, neighbours))
#     df_lst.append((person, neighbours_string))
# #     break

# %%
def dict_unique_counter(arr):
    return dict(zip(*np.unique(arr, return_counts=True)))

# %%
df_lst = []
for i, person in enumerate(tqdm(session_neighbours['person_id'].unique())):
    mask_person = session_neighbours['person_id'].isin([person])
    neighbours = np.concatenate(
        session_neighbours.loc[mask_person, 'session_neighbours'].values
    )
    neighbours = dict_unique_counter(neighbours)
    df_lst.append((person, neighbours))
#     if i > 100:
#         break
# Out:
# 100%|██████████| 22275/22275 [02:08<00:00, 173.77it/s]

# %%
session_neighbours = pd.DataFrame(
    df_lst,
    columns=['person_id', 'session_neighbours']
)

# %%
# %%time
# session_neighbours.to_pickle('../data/temp/session_neighbours.pkl')

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
vectorizer = DictVectorizer()
X = vectorizer.fit_transform(session_neighbours['session_neighbours'])
X
# Out:
# <22275x22275 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28818056 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import TruncatedSVD

# %%
tsvd = TruncatedSVD(n_components=1000)

# %%
X_tsvd = tsvd.fit_transform(X)

# %%
tsvd.components_
# Out:
# array([[ 3.90095707e-03,  3.08909882e-03,  1.13538446e-02, ...,
#          2.59800441e-07,  9.00882023e-05,  5.06341267e-05],
#        [ 7.85881694e-04,  9.30394956e-04, -1.30248867e-03, ...,
#          2.57115968e-07, -7.21357397e-05, -1.03959507e-05],
#        [-2.59863573e-03, -7.80258085e-04, -7.03425797e-03, ...,
#         -2.40750953e-07,  1.13689253e-04,  8.39425401e-05],
#        ...,
#        [-7.86452418e-03,  3.17340769e-03, -2.68720522e-02, ...,
#         -8.88258344e-05,  6.25100704e-04,  3.60528834e-04],
#        [-1.46044778e-02,  3.93472795e-03,  6.33255740e-02, ...,
#         -1.19814466e-04,  2.75576198e-04,  6.73703020e-04],
#        [ 1.77641204e-02, -9.26178078e-04, -1.86980702e-02, ...,
#         -1.18783116e-04, -5.51691742e-04,  1.66802672e-03]])

# %%
ebeddings = pd.concat([
    session_neighbours['person_id'],
    pd.DataFrame(X_tsvd)
], axis=1).set_index('person_id')
ebeddings
# Out:
#                   0          1          2          3          4          5    \
# person_id
# 325704     166.002614   6.573576 -41.414301   2.244714 -28.489260   0.253409
# 324951     132.861067  38.954129 -10.447080 -11.582624  19.816059  -9.987811
# 321482      65.357117  -5.133094  -9.393205 -24.902278  16.969505 -14.350675
# 209910      15.634815  -0.008990  -4.085451  -8.222346   3.304866  -4.064063
# 45072       33.761973  -1.265595 -10.571736 -16.344433   4.790306 -11.255527
# ...               ...        ...        ...        ...        ...        ...
# 277026       0.037502  -0.035583   0.025601  -0.029715  -0.014053  -0.014528
# 185078       0.109220  -0.103648   0.076914  -0.108989   0.047778   0.044147
# 345400       0.034339  -0.024479  -0.023742   0.093918  -0.002006  -0.019618
# 212554       0.497735  -0.138605  -0.228052  -0.139281   0.148449  -0.193796
# 299374       0.003359   0.001002  -0.003347   0.003527   0.002933  -0.005422
#
#                  6          7          8          9    ...       990  \
# person_id                                              ...
# 325704     -3.849836   1.928986   4.957353 -17.173485  ...  2.481825
# 324951    -10.942405 -13.587144  -9.747612  22.270913  ...  0.952618
# 321482     -9.814001   6.128002 -11.111390  11.775831  ... -2.699617
# 209910     -1.140591   3.962524  -3.692036   2.084211  ... -1.423569
# 45072       0.724642   6.300351  -8.438057   8.059858  ... -0.257331
# ...              ...        ...        ...        ...  ...       ...
# 277026     -0.037604  -0.012443   0.000730   0.021101  ...  0.051447
# 185078     -0.163251   0.025050  -0.090340   0.064043  ... -0.000152
# 345400     -0.023518   0.020015  -0.000108  -0.029962  ... -0.039639
# 212554      0.146380   0.026670  -0.093244   0.149415  ... -0.102378
# 299374      0.003171   0.007224   0.002236  -0.000607  ...  0.043707
#
#                 991       992       993       994       995       996  \
# person_id
# 325704     0.099077 -1.053812 -1.179852  2.233172  0.345858  2.008207
# 324951     0.320554 -0.142172  1.139293  1.042123  2.049437  0.787838
# 321482    -0.321509  0.788891 -2.200686 -0.860055 -0.178337 -0.032785
# 209910    -0.757997  0.794564 -1.090794 -0.104120  0.540161  0.114869
# 45072     -0.717752  1.971345 -0.529604 -1.818806 -0.497168 -0.982844
# ...             ...       ...       ...       ...       ...       ...
# 277026    -0.025509  0.023111 -0.003785 -0.019794 -0.007556  0.006162
# 185078     0.046933 -0.011860  0.121103 -0.115020 -0.035394 -0.060408
# 345400    -0.005406  0.002221  0.023458 -0.032905 -0.023366  0.016205
# 212554     0.000532  0.049269 -0.046504 -0.009925 -0.068488 -0.010377
# 299374    -0.010006  0.002599  0.011561  0.020405  0.053110 -0.031804
#
#                 997       998       999
# person_id
# 325704    -0.756790 -0.113385 -0.444923
# 324951    -0.160299  0.022737  0.190225
# 321482     2.211918 -0.155721  1.825814
# 209910     0.670853 -0.165722 -0.047591
# 45072      2.399521 -0.373256  3.357787
# ...             ...       ...       ...
# 277026     0.004009 -0.032558  0.027473
# 185078    -0.079502  0.114709 -0.053723
# 345400     0.008100  0.028412  0.041258
# 212554    -0.030665  0.043187 -0.007858
# 299374    -0.001745  0.010152  0.028381
#
# [22275 rows x 1000 columns]

# %%
# persons.merge(session_neighbours[['person_id']], on=['person_id'])

persons[persons['person_id'].isin([281542, 56683, 276125, 200082])]
# Out:
#         person_id                                        person_name  \
# 1373        56683                                              Bowie
# 21043      276125                                 Pink+Floyd+&+Floyd
# 25139       56683                          David+Bowie+&+Bing+Crosby
# 27674       56683                        David+Bowie+&+Pet+Shop+Boys
# 32700       56683                        David+Bowie+&+Phillip+Glass
# 40008       56683                         David+Bowie+&+Trent+Reznor
# 40030      200082                  Lil+Wayne+Feat.+Drake+&+Rick+Ross
# 44602      276125                               Pink+Floyd+&+The+Orb
# 44799       56683                          David+Bowie+&+Pat+Metheny
# 49995       56683                      David+Bowie+&+Freddie+Mercury
# 79045      276125                                     The+Pink+Floyd
# 90193      200082                                          Lil+Wayne
# 129430      56683                                        Dawid+Bowie
# 134688     200082                       Lil+Wayne+Ft.+Birdman+&+Euro
# 144998     200082                       Lil%27+Wayne+ft.+Nicki+Minaj
# 151438     200082                       Lil%27+Wayne+&+Juelz+Santana
# 153740      56683                         David+Bowie+&+Annie+Lennox
# 156888     200082                                       Lil%27+Wayne
# 207420     281542                          The+Prodigy+&+Tom+Morello
# 211327     276125                          Pink+Floyd+&+Candy+Dulfer
# 220195      56683                          David+Bowie+&+Mick+Jagger
# 222435     200082                                 Lil+Wayne+&+T-Pain
# 234814     200082               Lil+Wayne,+Static+Major+&+Kanye+West
# 236780      56683                        DAVID+BOWIE+&++FOO+FIGHTERS
# 237956      56683                             David+Bowie+&+Lou+Reed
# 256571      56683                             Bowie+&+Eno+meet+Glass
# 257937     200082                                  Lil+Wayne+&+Drake
# 263415     276125                             Pink+Floyd+&+D.J.+Fish
# 285598     281542                                       Prodigy,+The
# 287448      56683          David+Bowie+&+The+Tony+Visconti+Orchestra
# 300264     281542                                 The+Prodigy+&+Pain
# 305503      56683                   David+Bowie+&+Stevie+Ray+Vaughan
# 308147      56683                      David+Bowie+&+Nine+Inch+Nails
# 312095     200082                            LIL+WAYNE+&+NICKI+MINAJ
# 340746      56683               David+Bowie+&+Philadelphia+Orchestra
# 342357     276125                                         Pink+Floyd
# 361017     200082     Lil+Wayne+&+Nicki+Minaj+&+Rick+Ross+&+The+Game
# 370474     281542                                       Prod%C4%B1gy
# 391292      56683                          David+Bowie%2Fpat+Metheny
# 419678     281542                                 Prodigyremixed.com
# 420948      56683                   David+Bowie+&+Marianne+Faithfull
# 425170     200082                                Lil+Wayne+&+Phoenix
# 425545     281542                                            Prodigy
# 427620      56683                                David+Bowie+&+Queen
# 450252      56683                       David+Bowie+&+Massive+Attack
# 452189      56683               David+Bowie+&+The+Tony+Visconti+Trio
# 453800     276125                                         Pink+Floud
# 467016     281542  The+Prodigy+&+Pendulum+Vs+Limp+Bizkit+%5BRemix%5D
# 481543      56683                            Scumfrog+vs+David+Bowie
# 487168     281542                                        The+Prodigy
# 510180      56683                                       Bowie,+David
# 529402     200082                               Lil+Wayne+&+The+Sqad
# 535081      56683                                        David+Bowie
#
#                                  person_MBID
# 1373    5441c29d-3602-4898-b1a1-b77fa23b8e50
# 21043   83d91898-7763-47d7-b03b-b92132375c47
# 25139   5441c29d-3602-4898-b1a1-b77fa23b8e50
# 27674   5441c29d-3602-4898-b1a1-b77fa23b8e50
# 32700                                    NaN
# 40008   5441c29d-3602-4898-b1a1-b77fa23b8e50
# 40030                                    NaN
# 44602   83d91898-7763-47d7-b03b-b92132375c47
# 44799   5441c29d-3602-4898-b1a1-b77fa23b8e50
# 49995   5441c29d-3602-4898-b1a1-b77fa23b8e50
# 79045   83d91898-7763-47d7-b03b-b92132375c47
# 90193                                    NaN
# 129430  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 134688                                   NaN
# 144998                                   NaN
# 151438                                   NaN
# 153740  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 156888                                   NaN
# 207420  4a4ee089-93b1-4470-af9a-6ff575d32704
# 211327  83d91898-7763-47d7-b03b-b92132375c47
# 220195  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 222435                                   NaN
# 234814                                   NaN
# 236780  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 237956  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 256571  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 257937                                   NaN
# 263415                                   NaN
# 285598  4a4ee089-93b1-4470-af9a-6ff575d32704
# 287448                                   NaN
# 300264                                   NaN
# 305503  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 308147  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 312095                                   NaN
# 340746                                   NaN
# 342357  83d91898-7763-47d7-b03b-b92132375c47
# 361017                                   NaN
# 370474  2996c6a2-215d-4f78-aed6-81a130b04816
# 391292                                   NaN
# 419678  4a4ee089-93b1-4470-af9a-6ff575d32704
# 420948  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 425170                                   NaN
# 425545  2996c6a2-215d-4f78-aed6-81a130b04816
# 427620  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 450252  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 452189                                   NaN
# 453800                                   NaN
# 467016                                   NaN
# 481543  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 487168  4a4ee089-93b1-4470-af9a-6ff575d32704
# 510180  5441c29d-3602-4898-b1a1-b77fa23b8e50
# 529402                                   NaN
# 535081  5441c29d-3602-4898-b1a1-b77fa23b8e50

# %%
most_popular_persons = persons_playcount.sort_values(['playcount'], ascending=False).head(15)
most_popular_persons
# Out:
#         person_id  playcount
# 373252     373260  9400856.0
# 281536     281542  8003401.0
# 56679       56683  7038295.0
# 31356       31359  6413547.0
# 276119     276125  6337974.0
# 200076     200082  6247765.0
# 459777     459788  5781531.0
# 139130     139135  5767201.0
# 429264     429274  5751087.0
# 447087     447098  5547182.0
# 82951       82955  5298367.0
# 201102     201108  5250765.0
# 139389     139394  5246091.0
# 124217     124222  5031616.0
# 240011     240017  5013571.0

# %%
from scipy.spatial.distance import cosine

# %%
dist = [(i, cosine(ebeddings.loc[200082], row)) for i, row in ebeddings.iterrows()]
dist = pd.DataFrame(dist, columns=['person_id', 'cosine_dist'])
dist = dist.sort_values(['cosine_dist'])
dist
# Out:
#        person_id  cosine_dist
# 359       200082     0.000000
# 384       449356     0.043523
# 409       374349     0.047748
# 394       161570     0.052074
# 391        47600     0.054110
# ...          ...          ...
# 21329      79789     1.002057
# 21768     384701     1.002142
# 20536     408928     1.002309
# 20847     399501     1.002712
# 21922     438924     1.003882
#
# [22275 rows x 2 columns]

# %%
top_20 = dist['person_id'].iloc[1:51].values

# %%
persons[persons['person_id'].isin(top_20)].head(60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3e80ba818047> in <module>
# ----> 1 persons[persons['person_id'].isin(top_20)].head(60)
#
# NameError: name 'persons' is not defined

# %%
# session_neighbours = pd.read_csv('../data/temp/session_neighbours_500.csv', chunksize=1000)

# %%
# df_lst = []
# for df in tqdm(session_neighbours):
#     df['neighbours_dct'] = df['session_neighbours'].str.split(' ').apply(dict_unique_counter)
#     df_lst.append(df[['person_id', 'neighbours_dct']])
# #     break
# Out:
# 79it [02:52,  1.61it/s]

# %%
# vectorizer = CountVectorizer(max_features=10000)

# X = vectorizer.fit_transform(session_neighbours['session_neighbours'])

# X

# print(vectorizer.get_feature_names())

# print(X.toarray())

# %%
# session_neighbours['session_neighbours'] = session_neighbours['session_neighbours'].str.split(' ')

# %%
df_lst = []
for _, (person, neighbours) in tqdm(session_neighbours.iterrows()):
    df_lst.append(
        (person, dict_unique_counter(neighbours.split(' ')))
    )
#     break
# Out:
# 49940it [04:35, 11.22s/it]

# %%
df_lst
# Out:
# [(332749,
#   {'100758': 1,
#    '100889': 1,
#    '100904': 2,
#    '101590': 1,
#    '101611': 1,
#    '101774': 1,
#    '101903': 2,
#    '102300': 1,
#    '102352': 1,
#    '102835': 1,
#    '102923': 12,
#    '103018': 1,
#    '103260': 2,
#    '103498': 1,
#    '103673': 1,
#    '103871': 7,
#    '104139': 7,
#    '104207': 1,
#    '104243': 1,
#    '104521': 4,
#    '104676': 4,
#    '104885': 4,
#    '105144': 1,
#    '105256': 3,
#    '10617': 1,
#    '106222': 2,
#    '106237': 1,
#    '106350': 1,
#    '107039': 3,
#    '107103': 2,
#    '107168': 1,
#    '107364': 1,
#    '10764': 1,
#    '107743': 1,
#    '107750': 1,
#    '107846': 2,
#    '107920': 1,
#    '108114': 4,
#    '108228': 2,
#    '108267': 5,
#    '108734': 1,
#    '108742': 3,
#    '108766': 1,
#    '109145': 4,
#    '109210': 1,
#    '109301': 1,
#    '109433': 8,
#    '109444': 7,
#    '109595': 1,
#    '109597': 1,
#    '109784': 1,
#    '109854': 2,
#    '11005': 1,
#    '110264': 4,
#    '110578': 1,
#    '110729': 1,
#    '110792': 1,
#    '110855': 6,
#    '11092': 1,
#    '111203': 1,
#    '111262': 2,
#    '111494': 1,
#    '111610': 1,
#    '111754': 4,
#    '111790': 1,
#    '111905': 1,
#    '112035': 1,
#    '112091': 1,
#    '112213': 1,
#    '112317': 3,
#    '112321': 1,
#    '112443': 2,
#    '112565': 1,
#    '112778': 2,
#    '112876': 2,
#    '112993': 2,
#    '11328': 1,
#    '113444': 1,
#    '113616': 1,
#    '113916': 14,
#    '113944': 19,
#    '113972': 1,
#    '114195': 1,
#    '11423': 1,
#    '114283': 1,
#    '114467': 1,
#    '11456': 1,
#    '1146': 2,
#    '11467': 11,
#    '114685': 2,
#    '114772': 6,
#    '114844': 2,
#    '114943': 1,
#    '114966': 1,
#    '115051': 1,
#    '115120': 8,
#    '115432': 1,
#    '115611': 1,
#    '115633': 1,
#    '115942': 1,
#    '115971': 1,
#    '11617': 8,
#    '11622': 17,
#    '116222': 3,
#    '116605': 3,
#    '117020': 5,
#    '117027': 1,
#    '117090': 1,
#    '117140': 1,
#    '117210': 1,
#    '117509': 2,
#    '11774': 2,
#    '117784': 1,
#    '117985': 1,
#    '118045': 1,
#    '118175': 1,
#    '118791': 4,
#    '11887': 2,
#    '118901': 1,
#    '118919': 1,
#    '118970': 1,
#    '11949': 1,
#    '119491': 1,
#    '119901': 3,
#    '120313': 1,
#    '120461': 1,
#    '120594': 1,
#    '120602': 1,
#    '120605': 16,
#    '120765': 1,
#    '120937': 9,
#    '12114': 2,
#    '121281': 7,
#    '121343': 7,
#    '121403': 1,
#    '121508': 1,
#    '121525': 1,
#    '12160': 1,
#    '121728': 1,
#    '121878': 1,
#    '121972': 11,
#    '122056': 1,
#    '122374': 2,
#    '122496': 2,
#    '122559': 1,
#    '1226': 1,
#    '12269': 1,
#    '122873': 1,
#    '122934': 1,
#    '122978': 1,
#    '123235': 1,
#    '123373': 3,
#    '123386': 1,
#    '123440': 1,
#    '123896': 3,
#    '124041': 1,
#    '124222': 1,
#    '124519': 1,
#    '125614': 17,
#    '12631': 1,
#    '12709': 1,
#    '129': 1,
#    '13225': 5,
#    '133544': 1,
#    '133573': 1,
#    '133745': 1,
#    '133924': 1,
#    '134106': 2,
#    '134178': 3,
#    '134466': 1,
#    '134615': 2,
#    '135263': 1,
#    '135275': 1,
#    '135673': 1,
#    '136043': 2,
#    '136301': 1,
#    '136378': 1,
#    '136387': 4,
#    '136388': 1,
#    '136605': 1,
#    '136860': 1,
#    '137310': 1,
#    '137692': 2,
#    '137865': 1,
#    '137954': 2,
#    '138235': 1,
#    '138257': 3,
#    '138767': 5,
#    '138919': 1,
#    '138953': 5,
#    '13901': 1,
#    '13913': 2,
#    '139131': 1,
#    '139277': 1,
#    '139394': 11,
#    '139608': 3,
#    '139754': 4,
#    '139770': 1,
#    '140510': 3,
#    '140609': 1,
#    '140693': 1,
#    '141095': 4,
#    '141134': 3,
#    '141151': 2,
#    '14125': 1,
#    '141405': 1,
#    '141466': 1,
#    '141523': 5,
#    '141567': 1,
#    '14176': 1,
#    '141877': 2,
#    '141934': 1,
#    '142114': 1,
#    '142119': 3,
#    '142123': 2,
#    '14225': 1,
#    '142327': 1,
#    '142357': 7,
#    '14253': 1,
#    '142909': 1,
#    '142931': 1,
#    '143353': 1,
#    '143451': 1,
#    '143645': 1,
#    '143688': 1,
#    '144662': 1,
#    '144983': 1,
#    '145224': 6,
#    '145316': 1,
#    '145761': 1,
#    '146060': 1,
#    '146143': 1,
#    '146321': 2,
#    '146593': 1,
#    '146749': 5,
#    '146799': 1,
#    '146935': 5,
#    '14702': 1,
#    '147046': 5,
#    '147281': 1,
#    '147287': 2,
#    '147566': 1,
#    '1479': 1,
#    '147900': 1,
#    '147909': 1,
#    '148130': 1,
#    '14836': 1,
#    '148361': 1,
#    '148404': 2,
#    '148559': 2,
#    '148691': 1,
#    '148708': 3,
#    '148718': 2,
#    '148786': 1,
#    '14880': 1,
#    '148830': 2,
#    '148853': 1,
#    '149139': 1,
#    '1492': 1,
#    '149247': 1,
#    '149281': 1,
#    '149534': 2,
#    '149679': 1,
#    '149703': 1,
#    '149803': 1,
#    '149819': 1,
#    '149828': 1,
#    '150018': 2,
#    '150043': 1,
#    '150056': 3,
#    '150368': 1,
#    '150510': 1,
#    '15069': 1,
#    '150773': 1,
#    '150902': 1,
#    '151285': 1,
#    '151594': 6,
#    '152078': 2,
#    '152276': 3,
#    '152347': 1,
#    '152391': 10,
#    '152551': 3,
#    '152731': 3,
#    '152757': 1,
#    '152893': 1,
#    '153046': 2,
#    '153069': 1,
#    '153073': 2,
#    '15330': 1,
#    '153305': 1,
#    '153400': 1,
#    '153435': 1,
#    '153602': 2,
#    '153685': 2,
#    '153765': 9,
#    '153868': 1,
#    '154295': 9,
#    '154377': 1,
#    '154435': 1,
#    '154546': 2,
#    '154776': 1,
#    '155138': 1,
#    '155304': 1,
#    '155433': 1,
#    '155822': 1,
#    '155863': 1,
#    '156453': 1,
#    '156633': 2,
#    '157347': 1,
#    '157349': 39,
#    '157373': 1,
#    '157532': 1,
#    '157645': 1,
#    '1579': 1,
#    '158011': 2,
#    '158035': 3,
#    '158048': 3,
#    '158190': 3,
#    '158300': 1,
#    '158391': 2,
#    '159226': 1,
#    '159257': 1,
#    '159300': 1,
#    '159370': 12,
#    '159373': 1,
#    '159611': 1,
#    '159803': 3,
#    '159844': 4,
#    '159909': 1,
#    '159947': 1,
#    '160062': 1,
#    '160331': 5,
#    '16043': 1,
#    '160440': 1,
#    '160480': 1,
#    '16068': 2,
#    '161015': 1,
#    '161275': 3,
#    '161425': 2,
#    '161543': 12,
#    '161570': 4,
#    '161673': 3,
#    '161767': 1,
#    '161801': 5,
#    '161819': 19,
#    '161853': 1,
#    '161885': 2,
#    '162401': 1,
#    '162518': 1,
#    '163127': 1,
#    '163379': 1,
#    '163413': 1,
#    '163656': 1,
#    '163762': 1,
#    '1638': 1,
#    '163824': 7,
#    '163915': 1,
#    '164138': 1,
#    '164643': 2,
#    '165288': 4,
#    '165405': 1,
#    '165507': 1,
#    '165587': 1,
#    '165636': 33,
#    '165752': 2,
#    '166063': 1,
#    '16631': 5,
#    '166441': 1,
#    '166495': 1,
#    '166536': 1,
#    '167033': 1,
#    '167142': 1,
#    '167263': 1,
#    '167499': 2,
#    '167779': 1,
#    '167828': 1,
#    '167845': 1,
#    '168200': 1,
#    '168420': 5,
#    '168450': 1,
#    '168587': 2,
#    '168611': 1,
#    '168692': 1,
#    '169039': 1,
#    '169041': 4,
#    '169112': 1,
#    '169119': 5,
#    '169283': 1,
#    '169412': 2,
#    '16980': 1,
#    '169922': 5,
#    '17022': 1,
#    '17025': 2,
#    '170288': 7,
#    '170376': 3,
#    '170478': 1,
#    '170930': 1,
#    '170978': 1,
#    '171076': 5,
#    '171108': 5,
#    '171152': 1,
#    '172245': 1,
#    '172287': 1,
#    '172300': 2,
#    '172610': 1,
#    '172759': 1,
#    '172785': 1,
#    '172818': 2,
#    '172824': 1,
#    '173229': 1,
#    '173279': 1,
#    '173505': 4,
#    '173584': 1,
#    '17362': 1,
#    '173700': 1,
#    '173847': 3,
#    '17387': 1,
#    '174073': 6,
#    '174118': 1,
#    '174126': 1,
#    '174226': 3,
#    '174446': 1,
#    '174664': 1,
#    '174751': 1,
#    '174787': 1,
#    '17514': 1,
#    '175156': 3,
#    '175255': 1,
#    '175270': 2,
#    '175286': 4,
#    '175645': 1,
#    '175714': 5,
#    '175880': 1,
#    '176100': 1,
#    '176129': 1,
#    '176261': 2,
#    '176763': 2,
#    '176953': 1,
#    '177078': 1,
#    '177174': 1,
#    '177178': 1,
#    '17787': 1,
#    '178092': 2,
#    '178146': 1,
#    '178285': 1,
#    '178366': 1,
#    '178623': 1,
#    '179028': 1,
#    '179168': 1,
#    '179259': 1,
#    '179351': 2,
#    '179641': 1,
#    '179723': 3,
#    '179803': 1,
#    '179867': 1,
#    '179907': 6,
#    '179956': 3,
#    '180567': 1,
#    '180582': 1,
#    '180626': 4,
#    '180970': 30,
#    '181203': 1,
#    '181288': 1,
#    '181294': 1,
#    '181324': 1,
#    '181455': 2,
#    '181920': 2,
#    '182039': 4,
#    '18213': 1,
#    '182367': 1,
#    '18280': 1,
#    '182844': 2,
#    '182866': 1,
#    '182910': 1,
#    '183071': 2,
#    '183325': 3,
#    '183350': 1,
#    '183434': 12,
#    '183489': 1,
#    '183575': 2,
#    '183703': 2,
#    '184024': 2,
#    '184095': 1,
#    '184172': 1,
#    '184263': 2,
#    '184282': 1,
#    '184335': 1,
#    '184368': 1,
#    '184379': 1,
#    '184530': 2,
#    '184540': 9,
#    '184674': 1,
#    '185177': 1,
#    '18524': 1,
#    '185344': 1,
#    '185705': 1,
#    '185739': 1,
#    '185829': 1,
#    '185990': 1,
#    '186158': 1,
#    '186164': 1,
#    '18623': 1,
#    '186420': 1,
#    '186433': 1,
#    '186443': 1,
#    '186746': 2,
#    '187170': 2,
#    '187223': 1,
#    '18734': 1,
#    '187549': 1,
#    '187600': 1,
#    '187624': 1,
#    '187797': 1,
#    '187885': 1,
#    '187978': 1,
#    '188004': 1,
#    '188165': 1,
#    '18848': 9,
#    '188821': 1,
#    '188863': 6,
#    '18888': 1,
#    '188904': 1,
#    '189186': 1,
#    '189203': 2,
#    '189300': 1,
#    '189637': 2,
#    '189780': 2,
#    '189794': 2,
#    '189974': 28,
#    '190076': 1,
#    '190118': 1,
#    '190138': 1,
#    '190315': 2,
#    '190502': 3,
#    '190560': 1,
#    '190903': 1,
#    '191044': 1,
#    '191173': 1,
#    '191226': 4,
#    '191268': 1,
#    '191279': 1,
#    '191341': 1,
#    '191522': 1,
#    '192147': 3,
#    '192229': 1,
#    '19223': 1,
#    '192605': 1,
#    '192815': 7,
#    '19286': 2,
#    '193156': 1,
#    '19317': 1,
#    '193258': 1,
#    '193732': 1,
#    '19378': 1,
#    '194151': 1,
#    '194190': 7,
#    '194291': 1,
#    '19497': 1,
#    '195086': 5,
#    '195177': 1,
#    '195189': 1,
#    '195234': 1,
#    '195270': 1,
#    '195723': 1,
#    '195841': 2,
#    '196132': 1,
#    '196171': 1,
#    '196204': 1,
#    '196713': 1,
#    '197007': 1,
#    '19714': 1,
#    '197228': 1,
#    '197439': 2,
#    '197691': 1,
#    '19852': 2,
#    '198525': 1,
#    '198705': 1,
#    '199063': 1,
#    '199163': 2,
#    '199605': 1,
#    '199617': 1,
#    '199685': 2,
#    '199934': 1,
#    '200009': 1,
#    '200037': 2,
#    '200082': 8,
#    '200125': 2,
#    '200127': 2,
#    '200133': 2,
#    '200146': 1,
#    '2002': 5,
#    '200526': 1,
#    '200573': 1,
#    '20104': 4,
#    '201108': 1,
#    '201264': 1,
#    '201709': 1,
#    '201830': 1,
#    '201956': 1,
#    '202005': 17,
#    '202066': 5,
#    '202082': 1,
#    '202163': 1,
#    '202222': 1,
#    '202372': 1,
#    '202442': 1,
#    '202580': 2,
#    '202870': 2,
#    '202925': 2,
#    '203434': 7,
#    '203487': 1,
#    '203767': 1,
#    '203788': 1,
#    '203932': 8,
#    '203935': 1,
#    '204011': 1,
#    '204033': 3,
#    '204114': 1,
#    '204342': 1,
#    '204343': 3,
#    '204365': 1,
#    '204482': 3,
#    '204619': 1,
#    '204638': 6,
#    '204855': 1,
#    '205096': 1,
#    '206139': 1,
#    '206149': 1,
#    '206739': 2,
#    '20692': 1,
#    '206962': 1,
#    '20735': 3,
#    '207479': 1,
#    '20753': 1,
#    '207593': 1,
#    '208148': 1,
#    '208657': 2,
#    '208682': 4,
#    '208698': 3,
#    '209221': 1,
#    '209460': 1,
#    '209778': 13,
#    '209869': 1,
#    '209937': 1,
#    '210364': 1,
#    '210418': 1,
#    '210542': 1,
#    '210554': 1,
#    '21058': 1,
#    '210717': 1,
#    '210803': 3,
#    '210885': 1,
#    '210904': 2,
#    '211023': 3,
#    '211094': 14,
#    '211259': 2,
#    '211280': 1,
#    '211366': 1,
#    '211808': 1,
#    '211861': 6,
#    '212836': 1,
#    '213018': 3,
#    '213370': 1,
#    '213473': 1,
#    '213627': 1,
#    '213891': 1,
#    '21403': 13,
#    '214333': 1,
#    '214412': 1,
#    '21469': 1,
#    '214743': 1,
#    '215410': 1,
#    '215624': 1,
#    '215972': 1,
#    '216236': 4,
#    '21683': 1,
#    '21698': 4,
#    '217471': 1,
#    '217654': 2,
#    '218539': 1,
#    '218762': 1,
#    '218766': 1,
#    '219305': 1,
#    '219316': 1,
#    '21950': 1,
#    '219610': 2,
#    '220076': 1,
#    '220209': 2,
#    '220341': 3,
#    '220621': 1,
#    '221149': 1,
#    '221303': 2,
#    '221307': 15,
#    '221396': 8,
#    '221398': 1,
#    '221400': 1,
#    '221411': 5,
#    '221607': 5,
#    '221807': 1,
#    '221985': 2,
#    '222010': 1,
#    '222114': 1,
#    '222195': 1,
#    '222395': 1,
#    '223133': 1,
#    '223249': 3,
#    '223278': 1,
#    '223501': 1,
#    '224023': 1,
#    '224051': 5,
#    '224201': 1,
#    '224359': 1,
#    '224422': 1,
#    '224554': 1,
#    '224718': 1,
#    '225227': 1,
#    '22527': 2,
#    '225435': 1,
#    '225546': 5,
#    '225577': 2,
#    '225579': 1,
#    '225790': 1,
#    '225859': 1,
#    '225941': 1,
#    '226107': 1,
#    '226400': 1,
#    '226648': 2,
#    '226669': 5,
#    '227065': 1,
#    '227104': 1,
#    '227482': 1,
#    '227562': 1,
#    '228022': 1,
#    '228054': 4,
#    '228262': 1,
#    '228269': 1,
#    '228276': 2,
#    '228324': 3,
#    '228364': 2,
#    '228451': 2,
#    '228514': 7,
#    '228554': 1,
#    '228658': 1,
#    '228673': 1,
#    '228725': 1,
#    '228732': 2,
#    '228815': 1,
#    '228975': 1,
#    '229324': 1,
#    '229444': 2,
#    '229541': 1,
#    '230116': 1,
#    '230208': 1,
#    '230445': 1,
#    '230477': 1,
#    '230538': 1,
#    '230564': 6,
#    '230812': 1,
#    '230838': 1,
#    '230955': 1,
#    '231020': 1,
#    '231114': 1,
#    '231144': 1,
#    '231185': 2,
#    '231744': 1,
#    '231798': 1,
#    '232320': 1,
#    '232809': 2,
#    '232837': 3,
#    '232908': 1,
#    '232947': 1,
#    '232956': 1,
#    '233288': 1,
#    '233678': 1,
#    '233753': 1,
#    '233798': 1,
#    '233855': 1,
#    '233878': 1,
#    '233901': 1,
#    '233911': 1,
#    '23394': 2,
#    '233977': 1,
#    '234098': 1,
#    '234109': 1,
#    '234129': 1,
#    '234144': 1,
#    '234381': 2,
#    '234386': 2,
#    '23474': 1,
#    '234831': 1,
#    '234880': 1,
#    '234931': 1,
#    '234997': 1,
#    '23510': 1,
#    '235117': 1,
#    '235617': 1,
#    '235733': 1,
#    '235746': 1,
#    '235758': 1,
#    '235831': 20,
#    '235902': 2,
#    '236107': 1,
#    '236252': 1,
#    '236363': 5,
#    '236827': 1,
#    '236833': 1,
#    '237165': 1,
#    '237228': 1,
#    '23751': 1,
#    '237999': 1,
#    '238334': 1,
#    '238355': 1,
#    '238526': 1,
#    '238599': 4,
#    '238897': 1,
#    '238915': 5,
#    '238948': 1,
#    '23955': 1,
#    '239805': 1,
#    '239895': 1,
#    '24000': 1,
#    '240017': 2,
#    '240072': 1,
#    '240209': 1,
#    '240959': 5,
#    '240964': 1,
#    '241004': 2,
#    '241070': 2,
#    '241221': 1,
#    '24130': 1,
#    '241375': 1,
#    '241559': 1,
#    '241572': 1,
#    '241991': 1,
#    '242068': 3,
#    '242167': 1,
#    '242462': 6,
#    '24250': 2,
#    '242522': 1,
#    '242817': 1,
#    '242846': 1,
#    '242892': 1,
#    '242957': 1,
#    '243451': 1,
#    '243606': 1,
#    '243745': 1,
#    '244192': 1,
#    '245462': 1,
#    '245488': 3,
#    '245715': 40,
#    '245721': 1,
#    '245734': 1,
#    '246190': 1,
#    '246778': 1,
#    '246796': 5,
#    '247108': 1,
#    '247481': 4,
#    '247861': 1,
#    '247876': 1,
#    '248009': 4,
#    '248094': 1,
#    '248188': 3,
#    '248210': 3,
#    '248399': 1,
#    '248521': 3,
#    '248566': 1,
#    '248676': 2,
#    '248739': 2,
#    '248948': 9,
#    '249013': 1,
#    '249592': 2,
#    '249717': 1,
#    '249900': 1,
#    '24996': 1,
#    '249980': 1,
#    '250062': 7,
#    '250504': 1,
#    '250536': 1,
#    '250603': 4,
#    '250614': 1,
#    '250622': 6,
#    '250784': 1,
#    '251054': 1,
#    '251334': 1,
#    '251392': 1,
#    '251758': 2,
#    '251992': 3,
#    '252260': 1,
#    '25232': 2,
#    '252508': 1,
#    '252528': 1,
#    '252563': 2,
#    '252817': 4,
#    '252849': 6,
#    '25294': 4,
#    '252974': 2,
#    '25301': 1,
#    '25303': 1,
#    '253031': 1,
#    '253248': 1,
#    '253598': 1,
#    '253788': 6,
#    '254422': 1,
#    '254436': 2,
#    '254599': 1,
#    '254745': 1,
#    '255035': 1,
#    '255126': 1,
#    '255210': 1,
#    '255588': 1,
#    '255785': 1,
#    '256195': 1,
#    '256435': 1,
#    '25653': 1,
#    '256767': 2,
#    '257082': 1,
#    '257088': 1,
#    '257216': 2,
#    '257426': 2,
#    '257614': 1,
#    '257791': 2,
#    '257798': 11,
#    '257814': 1,
#    '257869': 1,
#    '258165': 1,
#    '258206': 1,
#    '258297': 1,
#    '258482': 4,
#    '258705': 1,
#    '258725': 1,
#    '258870': 1,
#    '258908': 1,
#    '258927': 6,
#    '259387': 1,
#    '259702': 1,
#    '260174': 1,
#    '260270': 1,
#    '260521': 1,
#    '260860': 2,
#    '261027': 1,
#    '261120': 1,
#    '261180': 4,
#    '261201': 16,
#    '261233': 1,
#    '261646': 1,
#    '261900': 1,
#    '262086': 1,
#    '262548': 2,
#    '262896': 1,
#    '262911': 1,
#    '263198': 1,
#    '263881': 6,
#    '263956': 3,
#    '264237': 4,
#    '264248': 11,
#    '264431': 1,
#    '265199': 2,
#    '265213': 6,
#    '26537': 12,
#    '265398': 1,
#    '26575': 1,
#    '266034': 1,
#    '266049': 1,
#    '266122': 1,
#    '266242': 1,
#    '266376': 10,
#    '266383': 1,
#    '266521': 2,
#    '266608': 2,
#    '266678': 1,
#    '267188': 1,
#    '267286': 2,
#    '267416': 5,
#    '267572': 1,
#    '267641': 2,
#    '267772': 1,
#    '267828': 6,
#    '267841': 1,
#    '267889': 2,
#    '267996': 1,
#    '268283': 1,
#    '26830': 1,
#    '268539': 1,
#    '268790': 1,
#    '26947': 1,
#    '269750': 1,
#    '269878': 1,
#    '269899': 2,
#    '27003': 1,
#    '270068': 1,
#    '270087': 1,
#    '270442': 1,
#    '270486': 1,
#    '270519': 11,
#    '271089': 1,
#    '27118': 1,
#    '271205': 1,
#    '271417': 4,
#    '27165': 1,
#    '271836': 1,
#    ...})]

# %%
print(session_neighbours.shape)
session_neighbours.head()
# Out:
# (190037, 2)
#    person_id                                 session_neighbours
# 0     332749  288070 124041 11423 442798 291362 52354 70915 ...
# 1     288070  332749 269833 5399 88671 109097 313066 147287 ...
# 2     154295  288626 341684 325050 46425 390636 360406 10326...
# 3     288626  154295 341684 325050 17514 203180 100758 29122...
# 4     341684  154295 288626 325050 84554 219840 318259 21984...

# %%
# session_neighbours.loc[0, 'session_neighbours']
# Out:
# '288070 124041 11423 442798 291362 52354 70915 245488 417177 399353 50321 359758 455930 399329 42218 21950 249900 332244 286859 110855 159300 159611 62678 84244 161015 114966 258705 371043 196132 287752 67354 369381 338261 27165 441362 452099 262896 121972 165405 70070 106222 55207 368250 155863 379822 234386 227562 434646 392962 86376 354892 73357 291837 360509 204114 364910 199934 85842 12631 62568 363805 348947 364597 386855 163656 353623 318475 214743 398072 52023 55136 258927 82359 62444 448656 34180 452823 47307 284448 221307 208657 108267 203935 328397 174073 273651 415453 3452 449356 304049 297016 117020 433041 277494 211094 323879 83974 413521 461101 235831 57272 74545 47552 383822 159844 42456 385714 460815 49971 279548 431811 55438 444371 41200 273573 283744 449220 242068 149679 76404 304591 267416 433523 14125 114283 411805 47154 253248 371765 236107 393820 42032 400168 74637 261027 314219 8102 303270 349103 362541 154377 305019 203487 273495 426900 123386 40656 233878 204855 359428 359738 318632 356929 34667 141405 334737 436980 167828 338916 221303 436008 234098 169112 451562 321616 431155 459139 3239 242846 258482 372902 320569 148361 207479 30345 260860 406420 383493 282544 83210 120461 163413 407598 250062 363390 410654 178366 435209 277205 87347 213627 420409 114943 121728 316825 440244 402051 449955 351912 345797 33594 25301 17787 220076 341034 167779 166063 376987 256195 446356 114195 164138 266678 422418 149803 267572 251054 393297 81625 88553 44557 74545 448656 189974 454824 455191 322732 8846 161819 448656 82146 120605 83974 180970 221396 272882 66656 3452 447098 397111 323879 120937 74545 9425 273654 273676 161543 119901 372354 273339 36777 325050 408323 114772 6862 141523 165636 183325 295069 225790 112565 81532 173584 379712 453951 447098 47307 323879 165636 273676 6862 141523 146749 120605 448656 34180 245715 75957 354893 295069 9425 37325 47113 438229 3452 287177 397111 374349 325050 36777 417783 52974 273676 208682 183325 84877 200082 323879 273339 165636 303002 204638 372354 192815 183325 57493 345863 257798 47552 50856 109444 157349 188863 159844 47425 412312 71529 73620 34726 434001 349105 448307 7082 72793 349769 74545 7085 121878 51312 286785 183071 168587 221396 87937 183434 272882 372354 228975 314734 283127 62444 372354 183434 74545 284716 171108 204638 50644 451516 202870 47638 189637 310330 314734 52545 47552 448307 428903 455191 157349 87937 192815 298594 8323 417853 458805 314734 47425 52545 453971 189637 252817 434001 138767 113944 286091 141934 447098 258165 462060 180970 281608 407742 124222 226669 370973 56940 86738 287159 61644 180970 201108 243451 458979 250062 447098 1479 462060 58041 448656 281608 407742 86738 55227 113916 154546 206139 179351 174751 266608 56940 370973 450852 47600 381849 428903 448656 462060 447098 273651 301719 289844 250062 65591 249592 287159 183071 283127 370095 448656 462060 295069 226669 249592 281608 412312 249980 266608 235831 448656 7085 266242 447098 343455 407742 295069 256767 47600 47113 47425 250062 265213 407700 180970 448608 448656 88792 447098 462060 179351 281608 4807 295069 448639 256767 47600 152551 323879 231744 287159 209778 273654 18888 310102 406728 161543 120937 245715 447098 248188 283873 235831 47552 448608 448656 113916 32223 53400 72793 18280 47307 47113 366893 200082 163824 157645 250062 252817 83974 226669 438229 157349 113616 281608 157349 359758 415063 34180 54198 299571 87999 409784 363268 80485 46185 47307 120605 28889 83974 180970 447098 245715 211094 33937 161819 245715 157349 180970 372354 231185 447098 235831 264248 211094 262086 36777 157349 235831 275369 211094 377440 87999 156633 157349 235831 275369 456780 47307 87999 228054 120605 323294 57473 157349 377440 456780 448307 47307 275369 49889 87999 228054 157349 26537 370746 231185 73297 49889 165636 377440 456780 305559 138767 463622 78662 157349 26537 323294 447098 28889 49889 165636 377440 69536 456780 374215 272882 379748 165636 26537 140510 190315 306847 49889 41755 ...

# %%
# %%time
# session_neighbours['neighbours_counts'] = session_neighbours['session_neighbours'].apply(dict_unique_counter)

# %%
df_lst = []
for _, (person, neighbours) in tqdm(session_neighbours.iterrows()):
    neighbours_counts = dict_unique_counter(neighbours)
    df_lst.append((person, neighbours_counts))
#     break
# Out:
# 100it [00:01, 79.74it/s]

# %%
session_neighbours = pd.DataFrame(
    df_lst,
    columns=['person_id', 'neighbours_counts']
)
# Out:
# [(332749,
#   {'100758': 1,
#    '100889': 1,
#    '100904': 2,
#    '101590': 1,
#    '101611': 1,
#    '101774': 1,
#    '101903': 2,
#    '102300': 1,
#    '102352': 1,
#    '102835': 1,
#    '102923': 12,
#    '103018': 1,
#    '103260': 2,
#    '103498': 1,
#    '103673': 1,
#    '103871': 7,
#    '104139': 7,
#    '104207': 1,
#    '104243': 1,
#    '104521': 4,
#    '104676': 4,
#    '104885': 4,
#    '105144': 1,
#    '105256': 3,
#    '10617': 1,
#    '106222': 2,
#    '106237': 1,
#    '106350': 1,
#    '107039': 3,
#    '107103': 2,
#    '107168': 1,
#    '107364': 1,
#    '10764': 1,
#    '107743': 1,
#    '107750': 1,
#    '107846': 2,
#    '107920': 1,
#    '108114': 4,
#    '108228': 2,
#    '108267': 5,
#    '108734': 1,
#    '108742': 3,
#    '108766': 1,
#    '109145': 4,
#    '109210': 1,
#    '109301': 1,
#    '109433': 8,
#    '109444': 7,
#    '109595': 1,
#    '109597': 1,
#    '109784': 1,
#    '109854': 2,
#    '11005': 1,
#    '110264': 4,
#    '110578': 1,
#    '110729': 1,
#    '110792': 1,
#    '110855': 6,
#    '11092': 1,
#    '111203': 1,
#    '111262': 2,
#    '111494': 1,
#    '111610': 1,
#    '111754': 4,
#    '111790': 1,
#    '111905': 1,
#    '112035': 1,
#    '112091': 1,
#    '112213': 1,
#    '112317': 3,
#    '112321': 1,
#    '112443': 2,
#    '112565': 1,
#    '112778': 2,
#    '112876': 2,
#    '112993': 2,
#    '11328': 1,
#    '113444': 1,
#    '113616': 1,
#    '113916': 14,
#    '113944': 19,
#    '113972': 1,
#    '114195': 1,
#    '11423': 1,
#    '114283': 1,
#    '114467': 1,
#    '11456': 1,
#    '1146': 2,
#    '11467': 11,
#    '114685': 2,
#    '114772': 6,
#    '114844': 2,
#    '114943': 1,
#    '114966': 1,
#    '115051': 1,
#    '115120': 8,
#    '115432': 1,
#    '115611': 1,
#    '115633': 1,
#    '115942': 1,
#    '115971': 1,
#    '11617': 8,
#    '11622': 17,
#    '116222': 3,
#    '116605': 3,
#    '117020': 5,
#    '117027': 1,
#    '117090': 1,
#    '117140': 1,
#    '117210': 1,
#    '117509': 2,
#    '11774': 2,
#    '117784': 1,
#    '117985': 1,
#    '118045': 1,
#    '118175': 1,
#    '118791': 4,
#    '11887': 2,
#    '118901': 1,
#    '118919': 1,
#    '118970': 1,
#    '11949': 1,
#    '119491': 1,
#    '119901': 3,
#    '120313': 1,
#    '120461': 1,
#    '120594': 1,
#    '120602': 1,
#    '120605': 16,
#    '120765': 1,
#    '120937': 9,
#    '12114': 2,
#    '121281': 7,
#    '121343': 7,
#    '121403': 1,
#    '121508': 1,
#    '121525': 1,
#    '12160': 1,
#    '121728': 1,
#    '121878': 1,
#    '121972': 11,
#    '122056': 1,
#    '122374': 2,
#    '122496': 2,
#    '122559': 1,
#    '1226': 1,
#    '12269': 1,
#    '122873': 1,
#    '122934': 1,
#    '122978': 1,
#    '123235': 1,
#    '123373': 3,
#    '123386': 1,
#    '123440': 1,
#    '123896': 3,
#    '124041': 1,
#    '124222': 1,
#    '124519': 1,
#    '125614': 17,
#    '12631': 1,
#    '12709': 1,
#    '129': 1,
#    '13225': 5,
#    '133544': 1,
#    '133573': 1,
#    '133745': 1,
#    '133924': 1,
#    '134106': 2,
#    '134178': 3,
#    '134466': 1,
#    '134615': 2,
#    '135263': 1,
#    '135275': 1,
#    '135673': 1,
#    '136043': 2,
#    '136301': 1,
#    '136378': 1,
#    '136387': 4,
#    '136388': 1,
#    '136605': 1,
#    '136860': 1,
#    '137310': 1,
#    '137692': 2,
#    '137865': 1,
#    '137954': 2,
#    '138235': 1,
#    '138257': 3,
#    '138767': 5,
#    '138919': 1,
#    '138953': 5,
#    '13901': 1,
#    '13913': 2,
#    '139131': 1,
#    '139277': 1,
#    '139394': 11,
#    '139608': 3,
#    '139754': 4,
#    '139770': 1,
#    '140510': 3,
#    '140609': 1,
#    '140693': 1,
#    '141095': 4,
#    '141134': 3,
#    '141151': 2,
#    '14125': 1,
#    '141405': 1,
#    '141466': 1,
#    '141523': 5,
#    '141567': 1,
#    '14176': 1,
#    '141877': 2,
#    '141934': 1,
#    '142114': 1,
#    '142119': 3,
#    '142123': 2,
#    '14225': 1,
#    '142327': 1,
#    '142357': 7,
#    '14253': 1,
#    '142909': 1,
#    '142931': 1,
#    '143353': 1,
#    '143451': 1,
#    '143645': 1,
#    '143688': 1,
#    '144662': 1,
#    '144983': 1,
#    '145224': 6,
#    '145316': 1,
#    '145761': 1,
#    '146060': 1,
#    '146143': 1,
#    '146321': 2,
#    '146593': 1,
#    '146749': 5,
#    '146799': 1,
#    '146935': 5,
#    '14702': 1,
#    '147046': 5,
#    '147281': 1,
#    '147287': 2,
#    '147566': 1,
#    '1479': 1,
#    '147900': 1,
#    '147909': 1,
#    '148130': 1,
#    '14836': 1,
#    '148361': 1,
#    '148404': 2,
#    '148559': 2,
#    '148691': 1,
#    '148708': 3,
#    '148718': 2,
#    '148786': 1,
#    '14880': 1,
#    '148830': 2,
#    '148853': 1,
#    '149139': 1,
#    '1492': 1,
#    '149247': 1,
#    '149281': 1,
#    '149534': 2,
#    '149679': 1,
#    '149703': 1,
#    '149803': 1,
#    '149819': 1,
#    '149828': 1,
#    '150018': 2,
#    '150043': 1,
#    '150056': 3,
#    '150368': 1,
#    '150510': 1,
#    '15069': 1,
#    '150773': 1,
#    '150902': 1,
#    '151285': 1,
#    '151594': 6,
#    '152078': 2,
#    '152276': 3,
#    '152347': 1,
#    '152391': 10,
#    '152551': 3,
#    '152731': 3,
#    '152757': 1,
#    '152893': 1,
#    '153046': 2,
#    '153069': 1,
#    '153073': 2,
#    '15330': 1,
#    '153305': 1,
#    '153400': 1,
#    '153435': 1,
#    '153602': 2,
#    '153685': 2,
#    '153765': 9,
#    '153868': 1,
#    '154295': 9,
#    '154377': 1,
#    '154435': 1,
#    '154546': 2,
#    '154776': 1,
#    '155138': 1,
#    '155304': 1,
#    '155433': 1,
#    '155822': 1,
#    '155863': 1,
#    '156453': 1,
#    '156633': 2,
#    '157347': 1,
#    '157349': 39,
#    '157373': 1,
#    '157532': 1,
#    '157645': 1,
#    '1579': 1,
#    '158011': 2,
#    '158035': 3,
#    '158048': 3,
#    '158190': 3,
#    '158300': 1,
#    '158391': 2,
#    '159226': 1,
#    '159257': 1,
#    '159300': 1,
#    '159370': 12,
#    '159373': 1,
#    '159611': 1,
#    '159803': 3,
#    '159844': 4,
#    '159909': 1,
#    '159947': 1,
#    '160062': 1,
#    '160331': 5,
#    '16043': 1,
#    '160440': 1,
#    '160480': 1,
#    '16068': 2,
#    '161015': 1,
#    '161275': 3,
#    '161425': 2,
#    '161543': 12,
#    '161570': 4,
#    '161673': 3,
#    '161767': 1,
#    '161801': 5,
#    '161819': 19,
#    '161853': 1,
#    '161885': 2,
#    '162401': 1,
#    '162518': 1,
#    '163127': 1,
#    '163379': 1,
#    '163413': 1,
#    '163656': 1,
#    '163762': 1,
#    '1638': 1,
#    '163824': 7,
#    '163915': 1,
#    '164138': 1,
#    '164643': 2,
#    '165288': 4,
#    '165405': 1,
#    '165507': 1,
#    '165587': 1,
#    '165636': 33,
#    '165752': 2,
#    '166063': 1,
#    '16631': 5,
#    '166441': 1,
#    '166495': 1,
#    '166536': 1,
#    '167033': 1,
#    '167142': 1,
#    '167263': 1,
#    '167499': 2,
#    '167779': 1,
#    '167828': 1,
#    '167845': 1,
#    '168200': 1,
#    '168420': 5,
#    '168450': 1,
#    '168587': 2,
#    '168611': 1,
#    '168692': 1,
#    '169039': 1,
#    '169041': 4,
#    '169112': 1,
#    '169119': 5,
#    '169283': 1,
#    '169412': 2,
#    '16980': 1,
#    '169922': 5,
#    '17022': 1,
#    '17025': 2,
#    '170288': 7,
#    '170376': 3,
#    '170478': 1,
#    '170930': 1,
#    '170978': 1,
#    '171076': 5,
#    '171108': 5,
#    '171152': 1,
#    '172245': 1,
#    '172287': 1,
#    '172300': 2,
#    '172610': 1,
#    '172759': 1,
#    '172785': 1,
#    '172818': 2,
#    '172824': 1,
#    '173229': 1,
#    '173279': 1,
#    '173505': 4,
#    '173584': 1,
#    '17362': 1,
#    '173700': 1,
#    '173847': 3,
#    '17387': 1,
#    '174073': 6,
#    '174118': 1,
#    '174126': 1,
#    '174226': 3,
#    '174446': 1,
#    '174664': 1,
#    '174751': 1,
#    '174787': 1,
#    '17514': 1,
#    '175156': 3,
#    '175255': 1,
#    '175270': 2,
#    '175286': 4,
#    '175645': 1,
#    '175714': 5,
#    '175880': 1,
#    '176100': 1,
#    '176129': 1,
#    '176261': 2,
#    '176763': 2,
#    '176953': 1,
#    '177078': 1,
#    '177174': 1,
#    '177178': 1,
#    '17787': 1,
#    '178092': 2,
#    '178146': 1,
#    '178285': 1,
#    '178366': 1,
#    '178623': 1,
#    '179028': 1,
#    '179168': 1,
#    '179259': 1,
#    '179351': 2,
#    '179641': 1,
#    '179723': 3,
#    '179803': 1,
#    '179867': 1,
#    '179907': 6,
#    '179956': 3,
#    '180567': 1,
#    '180582': 1,
#    '180626': 4,
#    '180970': 30,
#    '181203': 1,
#    '181288': 1,
#    '181294': 1,
#    '181324': 1,
#    '181455': 2,
#    '181920': 2,
#    '182039': 4,
#    '18213': 1,
#    '182367': 1,
#    '18280': 1,
#    '182844': 2,
#    '182866': 1,
#    '182910': 1,
#    '183071': 2,
#    '183325': 3,
#    '183350': 1,
#    '183434': 12,
#    '183489': 1,
#    '183575': 2,
#    '183703': 2,
#    '184024': 2,
#    '184095': 1,
#    '184172': 1,
#    '184263': 2,
#    '184282': 1,
#    '184335': 1,
#    '184368': 1,
#    '184379': 1,
#    '184530': 2,
#    '184540': 9,
#    '184674': 1,
#    '185177': 1,
#    '18524': 1,
#    '185344': 1,
#    '185705': 1,
#    '185739': 1,
#    '185829': 1,
#    '185990': 1,
#    '186158': 1,
#    '186164': 1,
#    '18623': 1,
#    '186420': 1,
#    '186433': 1,
#    '186443': 1,
#    '186746': 2,
#    '187170': 2,
#    '187223': 1,
#    '18734': 1,
#    '187549': 1,
#    '187600': 1,
#    '187624': 1,
#    '187797': 1,
#    '187885': 1,
#    '187978': 1,
#    '188004': 1,
#    '188165': 1,
#    '18848': 9,
#    '188821': 1,
#    '188863': 6,
#    '18888': 1,
#    '188904': 1,
#    '189186': 1,
#    '189203': 2,
#    '189300': 1,
#    '189637': 2,
#    '189780': 2,
#    '189794': 2,
#    '189974': 28,
#    '190076': 1,
#    '190118': 1,
#    '190138': 1,
#    '190315': 2,
#    '190502': 3,
#    '190560': 1,
#    '190903': 1,
#    '191044': 1,
#    '191173': 1,
#    '191226': 4,
#    '191268': 1,
#    '191279': 1,
#    '191341': 1,
#    '191522': 1,
#    '192147': 3,
#    '192229': 1,
#    '19223': 1,
#    '192605': 1,
#    '192815': 7,
#    '19286': 2,
#    '193156': 1,
#    '19317': 1,
#    '193258': 1,
#    '193732': 1,
#    '19378': 1,
#    '194151': 1,
#    '194190': 7,
#    '194291': 1,
#    '19497': 1,
#    '195086': 5,
#    '195177': 1,
#    '195189': 1,
#    '195234': 1,
#    '195270': 1,
#    '195723': 1,
#    '195841': 2,
#    '196132': 1,
#    '196171': 1,
#    '196204': 1,
#    '196713': 1,
#    '197007': 1,
#    '19714': 1,
#    '197228': 1,
#    '197439': 2,
#    '197691': 1,
#    '19852': 2,
#    '198525': 1,
#    '198705': 1,
#    '199063': 1,
#    '199163': 2,
#    '199605': 1,
#    '199617': 1,
#    '199685': 2,
#    '199934': 1,
#    '200009': 1,
#    '200037': 2,
#    '200082': 8,
#    '200125': 2,
#    '200127': 2,
#    '200133': 2,
#    '200146': 1,
#    '2002': 5,
#    '200526': 1,
#    '200573': 1,
#    '20104': 4,
#    '201108': 1,
#    '201264': 1,
#    '201709': 1,
#    '201830': 1,
#    '201956': 1,
#    '202005': 17,
#    '202066': 5,
#    '202082': 1,
#    '202163': 1,
#    '202222': 1,
#    '202372': 1,
#    '202442': 1,
#    '202580': 2,
#    '202870': 2,
#    '202925': 2,
#    '203434': 7,
#    '203487': 1,
#    '203767': 1,
#    '203788': 1,
#    '203932': 8,
#    '203935': 1,
#    '204011': 1,
#    '204033': 3,
#    '204114': 1,
#    '204342': 1,
#    '204343': 3,
#    '204365': 1,
#    '204482': 3,
#    '204619': 1,
#    '204638': 6,
#    '204855': 1,
#    '205096': 1,
#    '206139': 1,
#    '206149': 1,
#    '206739': 2,
#    '20692': 1,
#    '206962': 1,
#    '20735': 3,
#    '207479': 1,
#    '20753': 1,
#    '207593': 1,
#    '208148': 1,
#    '208657': 2,
#    '208682': 4,
#    '208698': 3,
#    '209221': 1,
#    '209460': 1,
#    '209778': 13,
#    '209869': 1,
#    '209937': 1,
#    '210364': 1,
#    '210418': 1,
#    '210542': 1,
#    '210554': 1,
#    '21058': 1,
#    '210717': 1,
#    '210803': 3,
#    '210885': 1,
#    '210904': 2,
#    '211023': 3,
#    '211094': 14,
#    '211259': 2,
#    '211280': 1,
#    '211366': 1,
#    '211808': 1,
#    '211861': 6,
#    '212836': 1,
#    '213018': 3,
#    '213370': 1,
#    '213473': 1,
#    '213627': 1,
#    '213891': 1,
#    '21403': 13,
#    '214333': 1,
#    '214412': 1,
#    '21469': 1,
#    '214743': 1,
#    '215410': 1,
#    '215624': 1,
#    '215972': 1,
#    '216236': 4,
#    '21683': 1,
#    '21698': 4,
#    '217471': 1,
#    '217654': 2,
#    '218539': 1,
#    '218762': 1,
#    '218766': 1,
#    '219305': 1,
#    '219316': 1,
#    '21950': 1,
#    '219610': 2,
#    '220076': 1,
#    '220209': 2,
#    '220341': 3,
#    '220621': 1,
#    '221149': 1,
#    '221303': 2,
#    '221307': 15,
#    '221396': 8,
#    '221398': 1,
#    '221400': 1,
#    '221411': 5,
#    '221607': 5,
#    '221807': 1,
#    '221985': 2,
#    '222010': 1,
#    '222114': 1,
#    '222195': 1,
#    '222395': 1,
#    '223133': 1,
#    '223249': 3,
#    '223278': 1,
#    '223501': 1,
#    '224023': 1,
#    '224051': 5,
#    '224201': 1,
#    '224359': 1,
#    '224422': 1,
#    '224554': 1,
#    '224718': 1,
#    '225227': 1,
#    '22527': 2,
#    '225435': 1,
#    '225546': 5,
#    '225577': 2,
#    '225579': 1,
#    '225790': 1,
#    '225859': 1,
#    '225941': 1,
#    '226107': 1,
#    '226400': 1,
#    '226648': 2,
#    '226669': 5,
#    '227065': 1,
#    '227104': 1,
#    '227482': 1,
#    '227562': 1,
#    '228022': 1,
#    '228054': 4,
#    '228262': 1,
#    '228269': 1,
#    '228276': 2,
#    '228324': 3,
#    '228364': 2,
#    '228451': 2,
#    '228514': 7,
#    '228554': 1,
#    '228658': 1,
#    '228673': 1,
#    '228725': 1,
#    '228732': 2,
#    '228815': 1,
#    '228975': 1,
#    '229324': 1,
#    '229444': 2,
#    '229541': 1,
#    '230116': 1,
#    '230208': 1,
#    '230445': 1,
#    '230477': 1,
#    '230538': 1,
#    '230564': 6,
#    '230812': 1,
#    '230838': 1,
#    '230955': 1,
#    '231020': 1,
#    '231114': 1,
#    '231144': 1,
#    '231185': 2,
#    '231744': 1,
#    '231798': 1,
#    '232320': 1,
#    '232809': 2,
#    '232837': 3,
#    '232908': 1,
#    '232947': 1,
#    '232956': 1,
#    '233288': 1,
#    '233678': 1,
#    '233753': 1,
#    '233798': 1,
#    '233855': 1,
#    '233878': 1,
#    '233901': 1,
#    '233911': 1,
#    '23394': 2,
#    '233977': 1,
#    '234098': 1,
#    '234109': 1,
#    '234129': 1,
#    '234144': 1,
#    '234381': 2,
#    '234386': 2,
#    '23474': 1,
#    '234831': 1,
#    '234880': 1,
#    '234931': 1,
#    '234997': 1,
#    '23510': 1,
#    '235117': 1,
#    '235617': 1,
#    '235733': 1,
#    '235746': 1,
#    '235758': 1,
#    '235831': 20,
#    '235902': 2,
#    '236107': 1,
#    '236252': 1,
#    '236363': 5,
#    '236827': 1,
#    '236833': 1,
#    '237165': 1,
#    '237228': 1,
#    '23751': 1,
#    '237999': 1,
#    '238334': 1,
#    '238355': 1,
#    '238526': 1,
#    '238599': 4,
#    '238897': 1,
#    '238915': 5,
#    '238948': 1,
#    '23955': 1,
#    '239805': 1,
#    '239895': 1,
#    '24000': 1,
#    '240017': 2,
#    '240072': 1,
#    '240209': 1,
#    '240959': 5,
#    '240964': 1,
#    '241004': 2,
#    '241070': 2,
#    '241221': 1,
#    '24130': 1,
#    '241375': 1,
#    '241559': 1,
#    '241572': 1,
#    '241991': 1,
#    '242068': 3,
#    '242167': 1,
#    '242462': 6,
#    '24250': 2,
#    '242522': 1,
#    '242817': 1,
#    '242846': 1,
#    '242892': 1,
#    '242957': 1,
#    '243451': 1,
#    '243606': 1,
#    '243745': 1,
#    '244192': 1,
#    '245462': 1,
#    '245488': 3,
#    '245715': 40,
#    '245721': 1,
#    '245734': 1,
#    '246190': 1,
#    '246778': 1,
#    '246796': 5,
#    '247108': 1,
#    '247481': 4,
#    '247861': 1,
#    '247876': 1,
#    '248009': 4,
#    '248094': 1,
#    '248188': 3,
#    '248210': 3,
#    '248399': 1,
#    '248521': 3,
#    '248566': 1,
#    '248676': 2,
#    '248739': 2,
#    '248948': 9,
#    '249013': 1,
#    '249592': 2,
#    '249717': 1,
#    '249900': 1,
#    '24996': 1,
#    '249980': 1,
#    '250062': 7,
#    '250504': 1,
#    '250536': 1,
#    '250603': 4,
#    '250614': 1,
#    '250622': 6,
#    '250784': 1,
#    '251054': 1,
#    '251334': 1,
#    '251392': 1,
#    '251758': 2,
#    '251992': 3,
#    '252260': 1,
#    '25232': 2,
#    '252508': 1,
#    '252528': 1,
#    '252563': 2,
#    '252817': 4,
#    '252849': 6,
#    '25294': 4,
#    '252974': 2,
#    '25301': 1,
#    '25303': 1,
#    '253031': 1,
#    '253248': 1,
#    '253598': 1,
#    '253788': 6,
#    '254422': 1,
#    '254436': 2,
#    '254599': 1,
#    '254745': 1,
#    '255035': 1,
#    '255126': 1,
#    '255210': 1,
#    '255588': 1,
#    '255785': 1,
#    '256195': 1,
#    '256435': 1,
#    '25653': 1,
#    '256767': 2,
#    '257082': 1,
#    '257088': 1,
#    '257216': 2,
#    '257426': 2,
#    '257614': 1,
#    '257791': 2,
#    '257798': 11,
#    '257814': 1,
#    '257869': 1,
#    '258165': 1,
#    '258206': 1,
#    '258297': 1,
#    '258482': 4,
#    '258705': 1,
#    '258725': 1,
#    '258870': 1,
#    '258908': 1,
#    '258927': 6,
#    '259387': 1,
#    '259702': 1,
#    '260174': 1,
#    '260270': 1,
#    '260521': 1,
#    '260860': 2,
#    '261027': 1,
#    '261120': 1,
#    '261180': 4,
#    '261201': 16,
#    '261233': 1,
#    '261646': 1,
#    '261900': 1,
#    '262086': 1,
#    '262548': 2,
#    '262896': 1,
#    '262911': 1,
#    '263198': 1,
#    '263881': 6,
#    '263956': 3,
#    '264237': 4,
#    '264248': 11,
#    '264431': 1,
#    '265199': 2,
#    '265213': 6,
#    '26537': 12,
#    '265398': 1,
#    '26575': 1,
#    '266034': 1,
#    '266049': 1,
#    '266122': 1,
#    '266242': 1,
#    '266376': 10,
#    '266383': 1,
#    '266521': 2,
#    '266608': 2,
#    '266678': 1,
#    '267188': 1,
#    '267286': 2,
#    '267416': 5,
#    '267572': 1,
#    '267641': 2,
#    '267772': 1,
#    '267828': 6,
#    '267841': 1,
#    '267889': 2,
#    '267996': 1,
#    '268283': 1,
#    '26830': 1,
#    '268539': 1,
#    '268790': 1,
#    '26947': 1,
#    '269750': 1,
#    '269878': 1,
#    '269899': 2,
#    '27003': 1,
#    '270068': 1,
#    '270087': 1,
#    '270442': 1,
#    '270486': 1,
#    '270519': 11,
#    '271089': 1,
#    '27118': 1,
#    '271205': 1,
#    '271417': 4,
#    '27165': 1,
#    '271836': 1,
#    ...})]

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)
D = [{11: 1, 12: 2}, {11: 3, 13: 1}]
X = v.fit_transform(D)
X
# Out:
# array([[1., 2., 0.],
#        [3., 0., 1.]])

# %% [markdown]
# # DRAFT

# %%
# %%time
# # не хватает мощности
# session_neighbours = (session_neighbours#.head(1000)
#     .groupby(['person_id'], as_index=False)
#     .agg({'session_neighbours' : lambda x: list(np.concatenate(x.values))})
# )

# %%
# 
sessions_extend[sessions_extend['playtime'].isin([-1])]
# Out:
#           session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 4            1873088  1406217037        -1          1    23183    838286
# 19            361604  1400260299        -1          1    40718    838286
# 40           2700519  1405970598        -1          1    24690    838286
# 58               846  1411031704        -1          1    40433    838286
# 82           2604837  1410191003        -1          1      377    838286
# ...              ...         ...       ...        ...      ...       ...
# 30732660     2704365  1392347333        -1          1    25560    366126
# 30732664      373369  1408739136        -1          1    40091   4789796
# 30732704     2751633  1408490773        -1          1    36788   3517368
# 30732765     1885736  1408391273        -1          1    26603   2749494
# 30732766     1885735  1408300690        -1          1    26603   3208862
#
#           track_playratio  playcount  person_id
# 4                     NaN      212.0     107103
# 19                    NaN      212.0     107103
# 40                    NaN      212.0     107103
# 58                    NaN      212.0     107103
# 82                    NaN      212.0     107103
# ...                   ...        ...        ...
# 30732660              NaN        4.0      45178
# 30732664              1.0        NaN     552076
# 30732704              NaN      166.0     439634
# 30732765              NaN      112.0     344789
# 30732766              NaN     1297.0     397734
#
# [587189 rows x 9 columns]

# %%
sessions_extend[sessions_extend['track_playratio'].isin([np.nan])]
# Out:
#           session_id   timestamp  playtime  numtracks  user_id  track_id  \
# 0             287144  1390231051      4547         23    44361   4698874
# 4            1873088  1406217037        -1          1    23183    838286
# 9            1591983  1421070443      6740         28    25592    838286
# 10           1591217  1399022203      3066         14    25458    838286
# 19            361604  1400260299        -1          1    40718    838286
# ...              ...         ...       ...        ...      ...       ...
# 30732763     1885731  1407078600       749          4    26603   3465265
# 30732765     1885736  1408391273        -1          1    26603   2749494
# 30732766     1885735  1408300690        -1          1    26603   3208862
# 30732769     2480038  1407956764       940          5    33058   2014661
# 30732785      540638  1415960966     18220         78    24700    720394
#
#           track_playratio  playcount  person_id
# 0                     NaN        NaN     142266
# 4                     NaN      212.0     107103
# 9                     NaN      212.0     107103
# 10                    NaN      212.0     107103
# 19                    NaN      212.0     107103
# ...                   ...        ...        ...
# 30732763              NaN      259.0     432719
# 30732765              NaN      112.0     344789
# 30732766              NaN     1297.0     397734
# 30732769              NaN     1466.0     252514
# 30732785              NaN      123.0      87396
#
# [4518858 rows x 9 columns]

# %%
sessions_extend['person_id'].nunique()
# Out:
# 560926

# %%
(sessions_extend['numtracks'] >= 5).sum() / sessions_extend.shape[0]
# Out:
# 0.9114987875489852

# %%
user_person_statistics = (sessions_extend
    .groupby(['user_id', 'person_id'], as_index=False)
    ['track_playratio'].median()
#     .agg({
#         'track_playratio':['count', 'sum', 'mean', 'median'],
#     })
)
user_person_statistics
# Out:
#          user_id  person_id  track_playratio
# 0              1      11467             1.00
# 1              1      11617             1.00
# 2              1      19627             1.01
# 3              1      28510             0.53
# 4              1      42218             1.43
# ...          ...        ...              ...
# 6305840    45175     361085             2.18
# 6305841    45175     390280             1.03
# 6305842    45175     426475             0.88
# 6305843    45175     438476              NaN
# 6305844    45175     446939             1.00
#
# [6305845 rows x 3 columns]

# %%
user_person_statistics.columns
# Out:
# Index(['user_id', 'person_id', 'track_playratio'], dtype='object')

# %%
from surprise import Dataset
# Load the movielens-100k dataset (download it if needed),
data = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from http://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /home/user/.surprise_data/ml-100k

# %%
from surprise import SVD

# Use the famous SVD algorithm.
svd = SVD()

# %%
users_listen_count = (sessions_extend
    .groupby(['user_id'], as_index=False)['track_playratio']
    .count()
    .rename(columns={'track_playratio':'listen_count'})
)
users_listen_count
# Out:
#        user_id  listen_count
# 0            1           404
# 1            2           672
# 2            3          1821
# 3            4          1013
# 4            5           173
# ...        ...           ...
# 45170    45171           174
# 45171    45172            16
# 45172    45173           364
# 45173    45174           351
# 45174    45175            71
#
# [45175 rows x 2 columns]

# %%
(users_listen_count['listen_count'] >= 50).sum() / users_listen_count.shape[0]
# Out:
# 0.8976646375207527
